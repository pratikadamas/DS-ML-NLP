# %%
corpus ="""Hello welcome  to pratik's giri NLP course.
Please subscribe! to my channel.
Like, share ? and comment.
"""

# %%
print(corpus)
# Out:
# Hello welcome  to pratik giri NLP course.
# Please subscribe! to my channel.
# Like, share ? and comment.

# %% [markdown]
# ## tokenization
# ## paragraph --->  Sentance

# %%
import nltk
nltk.download('punkt_tab')

# C:\Users\Pratik Giri\AppData\Roaming\nltk_data
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Pratik
# [nltk_data]     Giri\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)  # paragraph --->  Sentence
# separate based on " . ,! ,? "

# %%
documents
# Out:
# ["Hello welcome  to pratik's giri NLP course.",
#  'Please subscribe!',
#  'to my channel.',
#  'Like, share ?',
#  'and comment.']

# %%
type(documents)
# Out:
# list

# %% [markdown]
# #### paragraph -->words
# #### paragraph --> words

# %%
from nltk.tokenize import  word_tokenize

# %%
word_tokenize(corpus)
# all characters including special characters are treated as words
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'pratik',
#  'giri',
#  'NLP',
#  'course',
#  '.',
#  'Please',
#  'subscribe',
#  '!',
#  'to',
#  'my',
#  'channel',
#  '.',
#  'Like',
#  ',',
#  'share',
#  '?',
#  'and',
#  'comment',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# " ' , . ! ? all are treated as separate words"
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'pratik',
#  "'",
#  's',
#  'giri',
#  'NLP',
#  'course',
#  '.',
#  'Please',
#  'subscribe',
#  '!',
#  'to',
#  'my',
#  'channel',
#  '.',
#  'Like',
#  ',',
#  'share',
#  '?',
#  'and',
#  'comment',
#  '.']
