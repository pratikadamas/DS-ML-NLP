# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"E:\DS-ML-NLP\dataset\BreastCancser.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]

# %%
df.drop("Unnamed: 32",axis=1,inplace=True)

# %%
# Count the unique values in the diagnosis column
diagnosis_counts = df['diagnosis'].value_counts()
print(diagnosis_counts)
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
for col in features:
    df[col] = np.log1p(df[col])

# %%
df
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0    13.643895         M     2.943913      2.431857        4.818667
# 1    13.644150         M     3.071303      2.932260        4.897093
# 2    18.249903         M     3.029650      3.102342        4.875197
# 3    18.250465         M     2.519308      3.062456        4.364117
# 4    18.250585         M     3.058237      2.730464        4.913390
# ..         ...       ...          ...           ...             ...
# 564  13.739088         M     3.116178      3.152309        4.962845
# 565  13.739367         M     3.050694      3.375880        4.884316
# 566  13.739660         M     2.867899      3.370051        4.694096
# 567  13.739970         M     3.072693      3.412137        4.949469
# 568  11.437685         B     2.170196      3.240246        3.890186
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     6.909753         0.111899          0.244983        0.262441
# 1     7.190676         0.081340          0.075701        0.083330
# 2     7.093405         0.104000          0.148334        0.180153
# 3     5.958683         0.133219          0.249902        0.216240
# 4     7.168580         0.095583          0.124692        0.180653
# ..         ...              ...               ...             ...
# 564   7.299797         0.105261          0.109661        0.218252
# 565   7.140453         0.093308          0.098396        0.134531
# 566   6.755885         0.081165          0.097399        0.088478
# 567   7.143618         0.111362          0.244514        0.301141
# 568   5.204007         0.051292          0.042695        0.000000
#
#      concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0               0.137237  ...      3.272606       2.908539         5.223594
# 1               0.067818  ...      3.257712       3.194993         5.073923
# 2               0.120357  ...      3.201526       3.278276         5.033701
# 3               0.100026  ...      2.766948       3.314186         4.603869
# 4               0.099212  ...      3.158701       2.871868         5.031744
# ..                   ...  ...           ...            ...              ...
# 564             0.130063  ...      3.275256       3.310543         5.118592
# 565             0.093408  ...      3.206398       3.669951         5.049856
# 566             0.051662  ...      2.994732       3.558771         4.849684
# 567             0.141500  ...      3.286161       3.699325         5.223594
# 568             0.000000  ...      2.347176       3.445852         4.097008
#
#      area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      7.610853          0.150315           0.510185         0.537604
# 1      7.579168          0.116716           0.171092         0.216401
# 2      7.444249          0.134880           0.353821         0.371839
# 3      6.343353          0.190455           0.623958         0.522893
# 4      7.362645          0.128745           0.186480         0.336472
# ..          ...               ...                ...              ...
# 564    7.614805          0.131905           0.191694         0.344086
# 565    7.457032          0.110288           0.175800         0.278767
# 566    7.025538          0.107867           0.269569         0.292893
# 567    7.507690          0.152721           0.624922         0.662018
# 568    5.596939          0.086141           0.062449         0.000000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.235388        0.378505                 0.112346
# 1                0.170586        0.242946                 0.085278
# 2                0.217528        0.308440                 0.083955
# 3                0.229126        0.509104                 0.159565
# 4                0.150573        0.212204                 0.073975
# ..                    ...             ...                      ...
# 564              0.200161        0.187309                 0.068733
# 565              0.150831        0.228887                 0.064260
# 566              0.132606        0.200325                 0.075293
# 567              0.235072        0.342667                 0.116894
# 568              0.000000        0.252392                 0.068023
#
# [569 rows x 32 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


# remove target column
features = df.drop("diagnosis", axis=1).columns

for col in features:
    plt.figure(figsize=(6,4))
    sns.kdeplot(df[col], fill=True)
    plt.title(f"KDE Plot of {col}")
    plt.show()

# %%
for col in features:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Box Plot of {col}")
    plt.show()

# %%
for col in features:
    
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    
    df = df[(df[col] >= lower) & (df[col] <= upper)]

# %%
mapping = {'B': 0, 'M': 1}
df['diagnosis'] = df['diagnosis'].map(mapping)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
y=df['diagnosis']
X=df.drop("diagnosis",axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42
)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
# Logistic Regression model
model = LogisticRegression(max_iter=5000)

# Train the model
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
# Prediction
from sklearn.metrics import accuracy_score, classification_report
y_pred = model.predict(X_test_scaled)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9239130434782609
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95        67
#            1       0.95      0.76      0.84        25
#
#     accuracy                           0.92        92
#    macro avg       0.93      0.87      0.90        92
# weighted avg       0.93      0.92      0.92        92

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

pipeline = Pipeline([
    ("scaler", RobustScaler()),
    ("model", LogisticRegression(max_iter=1000))
])

# Train the model
pipeline.fit(x_train, y_train)

# Predict
y_pred = pipeline.predict(x_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Detailed report
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9347826086956522
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96        67
#            1       0.95      0.80      0.87        25
#
#     accuracy                           0.93        92
#    macro avg       0.94      0.89      0.91        92
# weighted avg       0.94      0.93      0.93        92

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(pipeline, X, y)

print("Cross validation accuracy:", scores.mean())
# Out:
# Cross validation accuracy: 0.9727508330248057
