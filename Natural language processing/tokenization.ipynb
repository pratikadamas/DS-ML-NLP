# %%
corpus ="""Hello welcome  to pratik's giri NLP course.
Please subscribe! to my channel.
Like, share ? and comment.
"""

# %%
print(corpus)
# Out:
# Hello welcome  to pratik's giri NLP course.
# Please subscribe! to my channel.
# Like, share ? and comment.

# %% [markdown]
# ## tokenization
# ## paragraph --->  Sentance

# %%
import os, sys

print("Current working directory:", os.getcwd())
print("Python path:", sys.path[:5])
# Out:
# Current working directory: e:\DS-ML-NLP\Natural language processing
# Python path: ['e:\\DS-ML-NLP\\venv\\python312.zip', 'e:\\DS-ML-NLP\\venv\\DLLs', 'e:\\DS-ML-NLP\\venv\\Lib', 'e:\\DS-ML-NLP\\venv', '']

# %%
import nltk
print(nltk.__file__)       # should show site-packages/nltk/__init__.py
import nltk.internals
print("Internals OK ✅")
# Out:
# e:\DS-ML-NLP\venv\Lib\site-packages\nltk\__init__.py
# Internals OK ✅

# %%
import nltk
print(nltk.__file__)
import nltk.data
import nltk.internals
print("NLTK works ✅")
# Out:
# e:\DS-ML-NLP\venv\Lib\site-packages\nltk\__init__.py
# NLTK works ✅

# %%
import nltk

# Tokenization
nltk.download("punkt")  # for word_tokenize and sent_tokenize

# Stopwords
nltk.download("stopwords")  # for stopword lists

# Lemmatizer
nltk.download("wordnet")  # for WordNetLemmatizer

# POS tagging
nltk.download("averaged_perceptron_tagger")  # for pos_tag


# C:\Users\Pratik Giri\AppData\Roaming\nltk_data
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Pratik
# [nltk_data]     Giri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Pratik
# [nltk_data]     Giri\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Pratik
# [nltk_data]     Giri\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Pratik Giri\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.tokenize import sent_tokenize
documents = sent_tokenize(corpus)

# %%
documents=sent_tokenize(corpus)  # paragraph --->  Sentence
# separate based on " . ,! ,? "

# %%
documents
# Out:
# ["Hello welcome  to pratik's giri NLP course.",
#  'Please subscribe!',
#  'to my channel.',
#  'Like, share ?',
#  'and comment.']

# %%
type(documents)
# Out:
# list

# %% [markdown]
# #### paragraph -->words
# #### paragraph --> words

# %%
from nltk.tokenize import  word_tokenize

# %%
word_tokenize(corpus)
# all characters including special characters are treated as words
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'pratik',
#  "'s",
#  'giri',
#  'NLP',
#  'course',
#  '.',
#  'Please',
#  'subscribe',
#  '!',
#  'to',
#  'my',
#  'channel',
#  '.',
#  'Like',
#  ',',
#  'share',
#  '?',
#  'and',
#  'comment',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# " ' , . ! ? all are treated as separate words"
# Out:
# ['Hello',
#  'welcome',
#  'to',
#  'pratik',
#  "'",
#  's',
#  'giri',
#  'NLP',
#  'course',
#  '.',
#  'Please',
#  'subscribe',
#  '!',
#  'to',
#  'my',
#  'channel',
#  '.',
#  'Like',
#  ',',
#  'share',
#  '?',
#  'and',
#  'comment',
#  '.']
