# %%
class car:
    pass

audi=car()
type(audi)
# Out:
# __main__.car

# %%
print(audi)
# Out:
# <__main__.car object at 0x00000254B6D64710>

# %%
audi.window=126
print(audi.window)
# Out:
# 126

# %%
class dog:
    #constructor
    
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
        
dog1=dog("tomy",2)
print(dog1.name)   
print(dog1)
# Out:
# tomy
# <__main__.dog object at 0x00000254B6EBD970>

# %%
#instance method
class dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
        
    def bark(self):
       print(f"{self.name} says woof!")
       
       
       
aa=dog("buddy",10)
aa.bark()
# Out:
# buddy says woof!

# %% [markdown]
# Inheritance

# %%
class car:
    def __init__(self,window,doors,enginetype):
        self.window=window
        self.doors=doors
        self.enginetype=enginetype
        
    def drive(self):
        print(f"the person drive {self.enginetype}")
        
c1=car(4,4,"PETROL")
c1.drive()
# Out:
# the person drive PETROL

# %%
class tesla(car):
    def __init__(self,window,doors,enginetype,selfdriving):
        super().__init__(window,doors,enginetype)
        self.selfdriving=selfdriving
        
        
    def selfdrive(self):
        print(f"tesla support self driving {self.selfdriving}")    
        
t1=tesla(4,2,"EV",'True')
t1.selfdrive()
t1.drive()
# Out:
# tesla support self driving True
# the person drive EV

# %%
class MyClass:
    # This is a class variable (static variable)
    class_variable = "I am a class variable"

    def __init__(self, instance_variable):
        self.instance_variable = instance_variable

# Accessing the class variable
print(MyClass.class_variable)

# Creating instances
obj1 = MyClass("Instance 1 data")
obj2 = MyClass("Instance 2 data")

# Both instances share the same class variable
print(obj1.class_variable)
print(obj2.class_variable)

# Modifying the class variable through the class
MyClass.class_variable = "Class variable modified"

print(obj1.class_variable)
print(obj2.class_variable)

# If you try to modify it through an instance, it creates an instance variable with the same name,
# rather than modifying the class variable.
obj1.class_variable = "This is now an instance variable for obj1"
print(obj1.class_variable) # This prints the instance variable
print(MyClass.class_variable) # The class variable remains unchanged
# Out:
# I am a class variable
# I am a class variable
# I am a class variable
# Class variable modified
# Class variable modified
# This is now an instance variable for obj1
# Class variable modified

# %% [markdown]
# abstraction
